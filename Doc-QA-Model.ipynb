# %% [markdown]
# RAG Pipeline:
#
#     A[User Query] --> B[Query Preprocessing]
#     B --> C[Query Embedding]
#     D[Document(s)] --> E[Document Loading & Parsing]
#     E --> F[Text Chunking]
#     F --> G[Chunk Embedding]
#     G --> H[(Vector Store)]
#     C --> I[Similarity Search]
#     H --> I
#     I --> J[Reranking]
#     J --> K[Context Retrieval]
#     K --> L[Prompt Engineering]
#     A --> L
#     L --> M[Large Language Model (LLM)]
#     M --> N[Answer Generation]
#     N --> O[Answer Post-processing]
#     O --> P[Final Answer & Sources]

# %% [markdown]
# Installing Dependencies

# %%
# !pip install symspellpy
# !pip install PyMuPDF
# !pip install faiss-cpu
# !pip install -q condacolab  # for installing faiss-gpu, dependency issues prevent direct installation
# !pip install "numpy<2"  # also for faiss
# for cpu, use !pip install faiss-cpu
# run this command only the first time, otherwise will create duplicates
# !wget https://raw.githubusercontent.com/wolfgarbe/SymSpell/master/SymSpell/frequency_dictionary_en_82_765.txt
# for installing faiss-gpu via condacolab
import condacolab
condacolab.install()
# Out:
# Collecting symspellpy
#   Downloading symspellpy-6.9.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting editdistpy>=0.1.3 (from symspellpy)
#   Downloading editdistpy-0.1.6-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Downloading symspellpy-6.9.0-py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 47.4 MB/s eta 0:00:00
# Downloading editdistpy-0.1.6-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.4/158.4 kB 16.3 MB/s eta 0:00:00
# Installing collected packages: editdistpy, symspellpy
# Successfully installed editdistpy-0.1.6 symspellpy-6.9.0
# Collecting PyMuPDF
#   Downloading pymupdf-1.26.0-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.26.0-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 73.6 MB/s eta 0:00:00
# Installing collected packages: PyMuPDF
# Successfully installed PyMuPDF-1.26.0
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (24.2)
# Downloading faiss_cpu-1.11.0-cp311-cp311-manylinux_2_28_x86_64.whl (31.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 15.8 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.11.0
# Collecting numpy<2
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.8 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 85.4 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4
# --2025-06-10 07:39:14--  https://raw.githubusercontent.com/wolfgarbe/SymSpell/master/SymSpell/frequency_dictionary_en_82_765.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1332881 (1.3M) [text/plain]
# Saving to: ‘frequency_dictionary_en_82_765.txt’
#
# frequency_dictionar 100%[===================>]   1.27M  --.-KB/s    in 0.04s
#
# 2025-06-10 07:39:14 (33.6 MB/s) - ‘frequency_dictionary_en_82_765.txt’ saved [1332881/1332881]
#
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:09
# 🔁 Restarting kernel...

# %%
# !mamba install -c pytorch -c nvidia -c conda-forge faiss-gpu cudatoolkit=11.8
# Out:
# Looking for: ['faiss-gpu', 'cudatoolkit=11.8']
#
# [+] 0.0s
# pytorch/linux-64 (check zst)                       Checked  0.1s
# [+] 0.0s
# pytorch/noarch (ch..  ⣾  pytorch/noarch (check zst)
# [+] 0.0s
# nvidia/linux-64 (c..  ⣾  nvidia/linux-64 (check zst)
# [+] 0.0s
# nvidia/noarch (che..  ⣾  nvidia/noarch (check zst)
# [+] 0.0s
# pytorch/linux-64  ⣾  pytorch/linux-64
# pytorch/noarch                                      10.2kB @ 104.6kB/s  0.1s
# [+] 0.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾
# nvidia/linux-64       ⣾
# nvidia/noarch         ⣾  nvidia/noarch
# nvidia/linux-64
# [+] 0.2s
# conda-forge/linux-64   5%
# conda-forge/noarch    12%[+] 0.3s
# conda-forge/linux-64  17%
# conda-forge/noarch    36%[+] 0.4s
# conda-forge/linux-64  25%
# conda-forge/noarch    54%[+] 0.5s
# conda-forge/linux-64  32%
# conda-forge/noarch    70%[+] 0.6s
# conda-forge/linux-64  39%
# conda-forge/noarch    87%conda-forge/noarch
# [+] 0.7s
# conda-forge/linux-64  48%[+] 0.8s
# conda-forge/linux-64  65%[+] 0.9s
# conda-forge/linux-64  71%[+] 1.0s
# conda-forge/linux-64  79%[+] 1.1s
# conda-forge/linux-64  86%[+] 1.2s
# conda-forge/linux-64  94%conda-forge/linux-64
#
# Pinned packages:
#   - python 3.11.*
#   - python 3.11.*
#   - python_abi 3.11.* *cp311*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - faiss-gpu
#    - cudatoolkit=11.8
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package               Version  Build                         Channel           Size
# ───────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────────────────────
#
#   + cudatoolkit          11.8.0  h4ba93d1_13                   conda-forge      716MB
#   + llvm-openmp          20.1.6  h024ca30_0                    conda-forge        3MB
#   + libgfortran5         14.2.0  hf1ad2bd_2                    conda-forge        1MB
#   + libhwloc             2.11.2  default_h0d58e46_1001         conda-forge        2MB
#   + libgfortran          14.2.0  h69a702a_2                    conda-forge       54kB
#   + tbb               2021.13.0  hceb3a55_1                    conda-forge      176kB
#   + libopenblas          0.3.29  pthreads_h94d23a6_0           conda-forge        6MB
#   + mkl                2023.0.0  h84fe81f_26648                conda-forge      161MB
#   + libblas               3.9.0  31_h59b9bed_openblas          conda-forge       17kB
#   + libcblas              3.9.0  31_he106b2a_openblas          conda-forge       17kB
#   + liblapack             3.9.0  31_h7ac8fdf_openblas          conda-forge       17kB
#   + numpy                1.26.4  py311h64a7726_0               conda-forge        8MB
#   + cuda-cudart         11.8.89  0                             nvidia           202kB
#   + libcublas         11.11.3.6  0                             nvidia           382MB
#   + libfaiss             1.11.0  h125bfce_0_cuda11.4.4         pytorch          190MB
#   + faiss-gpu            1.11.0  py3.11_h125bfce_0_cuda11.4.4  pytorch            3MB
#
#   Change:
# ───────────────────────────────────────────────────────────────────────────────────────
#
#   - _openmp_mutex           4.5  2_gnu                         conda-forge     Cached
#   + _openmp_mutex           4.5  3_kmp_llvm                    conda-forge        8kB
#
#   Upgrade:
# ───────────────────────────────────────────────────────────────────────────────────────
#
#   - ca-certificates  2024.12.14  hbcca054_0                    conda-forge     Cached
#   + ca-certificates   2025.4.26  hbd8a1cb_0                    conda-forge      152kB
#   - certifi          2024.12.14  pyhd8ed1ab_0                  conda-forge     Cached
#   + certifi           2025.4.26  pyhd8ed1ab_0                  conda-forge      157kB
#   - openssl               3.4.0  h7b32b05_1                    conda-forge     Cached
#   + openssl               3.5.0  h7b32b05_1                    conda-forge        3MB
#
#   Summary:
#
#   Install: 16 packages
#   Change: 1 packages
#   Upgrade: 3 packages
#
#   Total download: 1GB
#
# ───────────────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading        0%
# Extracting         0%_openmp_mutex                                        7.6kB @ 108.6kB/s  0.1s
# libgfortran5                                         1.5MB @  14.9MB/s  0.1s
# [+] 0.1s
# Downloading  (5)   1%
# Extracting   (2)  ⣾  libgfortran                                         53.7kB @ 458.5kB/s  0.0s
# libhwloc                                             2.4MB @  16.6MB/s  0.1s
# liblapack                                           16.8kB @ 111.4kB/s  0.0s
# llvm-openmp                                          3.2MB @  20.6MB/s  0.2s
# certifi                                            157.2kB @ 861.6kB/s  0.0s
# [+] 0.2s
# Downloading  (5)   1%
# Extracting   (6)  ⣾  cuda-cudart                                        202.0kB @ 967.0kB/s  0.1s
# libcblas                                            16.8kB @  77.3kB/s  0.0s
# tbb                                                176.0kB @ 697.9kB/s  0.0s
# faiss-gpu                                            3.4MB @  12.1MB/s  0.1s
# [+] 0.3s
# Downloading  (5)   2%
# Extracting   (8)  ⣾  [+] 0.4s
# Downloading  (5)   4%
# Extracting   (6)  ⣾  numpy                                                8.1MB @  17.4MB/s  0.2s
# [+] 0.5s
# Downloading  (5)   5%
# Extracting   (5)  ⣾  ca-certificates                                    152.3kB @ 303.9kB/s  0.0s
# libblas                                             16.9kB @  30.8kB/s  0.0s
# [+] 0.6s
# Downloading  (5)   6%
# Extracting   (6)  ⣾  openssl                                              3.1MB @   4.5MB/s  0.1s
# [+] 0.7s
# Downloading  (5)   7%
# Extracting   (6)  ⣾  [+] 0.8s
# Downloading  (5)   7%
# Extracting   (6)  ⣾  [+] 0.9s
# Downloading  (5)   9%
# Extracting   (5)  ⣾  libopenblas                                          5.9MB @   6.4MB/s  0.2s
# [+] 1.0s
# Downloading  (4)   9%
# Extracting   (5)  ⣾  [+] 1.1s
# Downloading  (4)  11%
# Extracting   (5)  ⣾  [+] 1.2s
# Downloading  (4)  13%
# Extracting   (5)  ⣾  [+] 1.3s
# Downloading  (4)  15%
# Extracting   (5)  ⣾  [+] 1.4s
# Downloading  (4)  16%
# Extracting   (5)  ⣾  [+] 1.5s
# Downloading  (4)  17%
# Extracting   (4)  ⣾  [+] 1.6s
# Downloading  (4)  18%
# Extracting   (3)  ⣾  [+] 1.7s
# Downloading  (4)  20%
# Extracting   (2)  ⣾  [+] 1.8s
# Downloading  (4)  22%
# Extracting   (1)  ⣾  [+] 1.9s
# Downloading  (4)  23%
# Extracting   (1)  ⣾  [+] 2.0s
# Downloading  (4)  25%
# Extracting        80%[+] 2.1s
# Downloading  (4)  27%
# Extracting        80%[+] 2.2s
# Downloading  (4)  30%
# Extracting        80%[+] 2.3s
# Downloading  (4)  31%
# Extracting        80%[+] 2.4s
# Downloading  (4)  32%
# Extracting        80%[+] 2.5s
# Downloading  (4)  35%
# Extracting        80%[+] 2.6s
# Downloading  (4)  35%
# Extracting        80%[+] 2.7s
# Downloading  (4)  37%
# Extracting        80%[+] 2.8s
# Downloading  (4)  40%
# Extracting        80%[+] 2.9s
# Downloading  (4)  42%
# Extracting        80%[+] 3.0s
# Downloading  (4)  43%
# Extracting        80%mkl                                                161.4MB @  52.1MB/s  3.0s
# [+] 3.1s
# Downloading  (3)  44%
# Extracting        80%[+] 3.2s
# Downloading  (3)  46%
# Extracting   (1)  ⣾  [+] 3.3s
# Downloading  (3)  48%
# Extracting   (1)  ⣾  [+] 3.4s
# Downloading  (3)  49%
# Extracting   (1)  ⣾  [+] 3.5s
# Downloading  (3)  51%
# Extracting   (1)  ⣾  [+] 3.6s
# Downloading  (3)  53%
# Extracting   (1)  ⣾  libfaiss                                           190.0MB @  52.3MB/s  3.4s
# [+] 3.7s
# Downloading  (2)  55%
# Extracting   (2)  ⣾  [+] 3.8s
# Downloading  (2)  55%
# Extracting   (2)  ⣾  [+] 3.9s
# Downloading  (2)  55%
# Extracting   (2)  ⣾  [+] 4.0s
# Downloading  (2)  55%
# Extracting   (2)  ⣾  [+] 4.1s
# Downloading  (2)  55%
# Extracting   (2)  ⣾  [+] 4.2s
# Downloading  (2)  55%
# Extracting   (2)  ⣾  [+] 4.3s
# Downloading  (2)  55%
# Extracting   (2)  ⣾  [+] 4.4s
# Downloading  (2)  55%
# Extracting   (2)  ⣾  [+] 4.5s
# Downloading  (2)  55%
# Extracting   (2)  ⣾  [+] 4.6s
# Downloading  (2)  55%
# Extracting   (2)  ⣾  [+] 4.7s
# Downloading  (2)  55%
# Extracting   (2)  ⣾  [+] 4.8s
# Downloading  (2)  55%
# Extracting   (2)  ⣾  [+] 4.9s
# Downloading  (2)  55%
# Extracting   (2)  ⣾  [+] 5.0s
# Downloading  (2)  55%
# Extracting   (2)  ⣾  [+] 5.1s
# Downloading  (2)  55%
# Extracting   (2)  ⣾  [+] 5.2s
# Downloading  (2)  55%
# Extracting   (2)  ⣾  [+] 5.3s
# Downloading  (2)  55%
# Extracting   (2)  ⣾  [+] 5.4s
# Downloading  (2)  55%
# Extracting   (2)  ⣾  [+] 5.5s
# Downloading  (2)  55%
# Extracting   (2)  ⣾  [+] 5.6s
# Downloading  (2)  55%
# Extracting   (2)  ⣾  [+] 5.7s
# Downloading  (2)  55%
# Extracting   (2)  ⣾  [+] 5.8s
# Downloading  (2)  56%
# Extracting   (2)  ⣾  [+] 5.9s
# Downloading  (2)  57%
# Extracting   (2)  ⣾  [+] 6.0s
# Downloading  (2)  58%
# Extracting   (2)  ⣾  [+] 6.1s
# Downloading  (2)  59%
# Extracting   (2)  ⣾  [+] 6.2s
# Downloading  (2)  60%
# Extracting   (2)  ⣾  [+] 6.3s
# Downloading  (2)  60%
# Extracting   (2)  ⣾  [+] 6.4s
# Downloading  (2)  61%
# Extracting   (2)  ⣾  [+] 6.5s
# Downloading  (2)  62%
# Extracting   (2)  ⣾  [+] 6.6s
# Downloading  (2)  63%
# Extracting   (2)  ⣾  [+] 6.7s
# Downloading  (2)  65%
# Extracting   (2)  ⣾  [+] 6.8s
# Downloading  (2)  66%
# Extracting   (2)  ⣾  [+] 6.9s
# Downloading  (2)  67%
# Extracting   (2)  ⣾  [+] 7.0s
# Downloading  (2)  68%
# Extracting   (2)  ⣾  [+] 7.1s
# Downloading  (2)  68%
# Extracting   (2)  ⣾  [+] 7.2s
# Downloading  (2)  69%
# Extracting   (2)  ⣾  [+] 7.3s
# Downloading  (2)  71%
# Extracting   (2)  ⣾  [+] 7.4s
# Downloading  (2)  72%
# Extracting   (2)  ⣾  [+] 7.5s
# Downloading  (2)  73%
# Extracting   (2)  ⣾  [+] 7.6s
# Downloading  (2)  74%
# Extracting   (2)  ⣾  [+] 7.7s
# Downloading  (2)  74%
# Extracting   (2)  ⣾  [+] 7.8s
# Downloading  (2)  76%
# Extracting   (2)  ⣾  [+] 7.9s
# Downloading  (2)  76%
# Extracting   (2)  ⣾  [+] 8.0s
# Downloading  (2)  76%
# Extracting   (2)  ⣾  [+] 8.1s
# Downloading  (2)  76%
# Extracting   (2)  ⣾  [+] 8.2s
# Downloading  (2)  76%
# Extracting   (2)  ⣾  [+] 8.3s
# Downloading  (2)  76%
# Extracting   (2)  ⣾  [+] 8.4s
# Downloading  (2)  76%
# Extracting   (2)  ⣾  [+] 8.5s
# Downloading  (2)  76%
# Extracting   (2)  ⣾  [+] 8.6s
# Downloading  (2)  76%
# Extracting   (2)  ⣾  [+] 8.7s
# Downloading  (2)  76%
# Extracting   (2)  ⣾  [+] 8.8s
# Downloading  (2)  76%
# Extracting   (2)  ⣾  [+] 8.9s
# Downloading  (2)  76%
# Extracting   (2)  ⣾  [+] 9.0s
# Downloading  (2)  76%
# Extracting   (2)  ⣾  [+] 9.1s
# Downloading  (2)  76%
# Extracting   (2)  ⣾  [+] 9.2s
# Downloading  (2)  76%
# Extracting   (2)  ⣾  [+] 9.3s
# Downloading  (2)  76%
# Extracting   (2)  ⣾  [+] 9.4s
# Downloading  (2)  76%
# Extracting   (2)  ⣾  [+] 9.5s
# Downloading  (2)  76%
# Extracting   (2)  ⣾  [+] 9.6s
# Downloading  (2)  76%
# Extracting   (2)  ⣾  [+] 9.7s
# Downloading  (2)  76%
# Extracting   (2)  ⣾  [+] 9.8s
# Downloading  (2)  76%
# Extracting   (2)  ⣾  [+] 9.9s
# Downloading  (2)  77%
# Extracting   (2)  ⣾  libcublas                                          381.6MB @  38.2MB/s  9.8s
# [+] 10.0s
# Downloading  (1)  78%
# Extracting   (3)  ⣾  [+] 10.1s
# Downloading  (1)  79%
# Extracting   (3)  ⣾  [+] 10.2s
# Downloading  (1)  80%
# Extracting   (3)  ⣾  [+] 10.3s
# Downloading  (1)  80%
# Extracting   (3)  ⣾  [+] 10.4s
# Downloading  (1)  80%
# Extracting   (3)  ⣾  [+] 10.5s
# Downloading  (1)  81%
# Extracting   (3)  ⣾  [+] 10.6s
# Downloading  (1)  82%
# Extracting   (3)  ⣾  [+] 10.7s
# Downloading  (1)  82%
# Extracting   (3)  ⣾  [+] 10.8s
# Downloading  (1)  82%
# Extracting   (3)  ⣾  [+] 10.9s
# Downloading  (1)  82%
# Extracting   (3)  ⣾  [+] 11.0s
# Downloading  (1)  82%
# Extracting   (3)  ⣾  [+] 11.1s
# Downloading  (1)  83%
# Extracting   (3)  ⣾  [+] 11.2s
# Downloading  (1)  83%
# Extracting   (3)  ⣾  [+] 11.3s
# Downloading  (1)  84%
# Extracting   (3)  ⣾  [+] 11.4s
# Downloading  (1)  84%
# Extracting   (3)  ⣾  [+] 11.5s
# Downloading  (1)  85%
# Extracting   (3)  ⣾  [+] 11.6s
# Downloading  (1)  86%
# Extracting   (3)  ⣾  [+] 11.7s
# Downloading  (1)  87%
# Extracting   (3)  ⣾  [+] 11.8s
# Downloading  (1)  88%
# Extracting   (3)  ⣾  [+] 11.9s
# Downloading  (1)  89%
# Extracting   (3)  ⣾  [+] 12.0s
# Downloading  (1)  89%
# Extracting   (3)  ⣾  [+] 12.1s
# Downloading  (1)  91%
# Extracting   (3)  ⣾  [+] 12.2s
# Downloading  (1)  91%
# Extracting   (3)  ⣾  [+] 12.3s
# Downloading  (1)  92%
# Extracting   (3)  ⣾  [+] 12.4s
# Downloading  (1)  93%
# Extracting   (3)  ⣾  [+] 12.5s
# Downloading  (1)  93%
# Extracting   (3)  ⣾  [+] 12.6s
# Downloading  (1)  93%
# Extracting   (3)  ⣾  [+] 12.7s
# Downloading  (1)  94%
# Extracting   (3)  ⣾  [+] 12.8s
# Downloading  (1)  95%
# Extracting   (3)  ⣾  [+] 12.9s
# Downloading  (1)  96%
# Extracting   (3)  ⣾  [+] 13.0s
# Downloading  (1)  96%
# Extracting   (3)  ⣾  [+] 13.1s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 13.2s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 13.3s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 13.4s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 13.5s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 13.6s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 13.7s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 13.8s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 13.9s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 14.0s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 14.1s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 14.2s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 14.3s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 14.4s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 14.5s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 14.6s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 14.7s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 14.8s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 14.9s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 15.0s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 15.1s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 15.2s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 15.3s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 15.4s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 15.5s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 15.6s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 15.7s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 15.8s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 15.9s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 16.0s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 16.1s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 16.2s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 16.3s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 16.4s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 16.5s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 16.6s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 16.7s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 16.8s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 16.9s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 17.0s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 17.1s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 17.2s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 17.3s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 17.4s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 17.5s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 17.6s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 17.7s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 17.8s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 17.9s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 18.0s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 18.1s
# Downloading  (1)  97%
# Extracting   (3)  ⣾  [+] 18.2s
# Downloading  (1)  98%
# Extracting   (3)  ⣾  [+] 18.3s
# Downloading  (1)  99%
# Extracting   (3)  ⣾  [+] 18.4s
# Downloading  (1) 100%
# Extracting   (3)  ⣾  cudatoolkit                                        715.6MB @  38.8MB/s 18.4s
# [+] 18.5s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 18.6s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 18.7s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 18.8s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 18.9s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 19.0s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 19.1s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 19.2s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 19.3s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 19.4s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 19.5s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 19.6s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 19.7s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 19.8s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 19.9s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 20.0s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 20.1s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 20.2s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 20.3s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 20.4s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 20.5s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 20.6s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 20.7s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 20.8s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 20.9s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 21.0s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 21.1s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 21.2s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 21.3s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 21.4s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 21.5s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 21.6s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 21.7s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 21.8s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 21.9s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 22.0s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 22.1s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 22.2s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 22.3s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 22.4s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 22.5s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 22.6s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 22.7s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 22.8s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 22.9s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 23.0s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 23.1s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 23.2s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 23.3s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 23.4s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 23.5s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 23.6s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 23.7s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 23.8s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 23.9s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 24.0s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 24.1s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 24.2s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 24.3s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 24.4s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 24.5s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 24.6s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 24.7s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 24.8s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 24.9s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 25.0s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 25.1s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 25.2s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 25.3s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 25.4s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 25.5s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 25.6s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 25.7s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 25.8s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 25.9s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 26.0s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 26.1s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 26.2s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 26.3s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 26.4s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 26.5s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 26.6s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 26.7s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 26.8s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 26.9s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 27.0s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 27.1s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 27.2s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 27.3s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 27.4s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 27.5s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 27.6s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 27.7s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 27.8s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 27.9s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 28.0s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 28.1s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 28.2s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 28.3s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 28.4s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 28.5s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 28.6s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 28.7s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 28.8s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 28.9s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 29.0s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 29.1s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 29.2s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 29.3s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 29.4s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 29.5s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 29.6s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 29.7s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 29.8s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 29.9s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 30.0s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 30.1s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 30.2s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 30.3s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 30.4s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 30.5s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 30.6s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 30.7s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 30.8s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 30.9s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 31.0s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 31.1s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 31.2s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 31.3s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 31.4s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 31.5s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 31.6s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 31.7s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 31.8s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 31.9s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 32.0s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 32.1s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 32.2s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 32.3s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 32.4s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 32.5s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 32.6s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 32.7s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 32.8s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 32.9s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 33.0s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 33.1s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 33.2s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 33.3s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 33.4s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 33.5s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 33.6s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 33.7s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 33.8s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 33.9s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 34.0s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 34.1s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 34.2s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 34.3s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 34.4s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 34.5s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 34.6s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 34.7s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 34.8s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 34.9s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 35.0s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 35.1s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 35.2s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 35.3s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 35.4s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 35.5s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 35.6s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 35.7s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 35.8s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 35.9s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 36.0s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 36.1s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 36.2s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 36.3s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 36.4s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 36.5s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 36.6s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 36.7s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 36.8s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 36.9s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 37.0s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 37.1s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 37.2s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 37.3s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 37.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 37.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 37.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 37.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 37.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 37.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 38.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 38.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 38.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 38.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 38.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 38.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 38.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 38.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 38.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 38.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 39.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 39.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 39.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 39.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 39.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 39.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 39.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 39.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 39.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 39.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 40.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 40.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 40.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 40.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 40.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 40.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 40.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 40.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 40.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 40.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 41.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 41.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 41.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 41.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 41.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 41.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 41.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 41.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 41.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 41.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 42.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 42.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 42.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 42.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 42.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 42.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 42.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 42.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 42.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 42.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 43.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 43.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 43.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 43.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 43.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 43.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 43.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 43.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 43.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 43.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 44.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 44.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 44.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 44.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 44.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 44.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 44.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 44.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 44.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 44.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 45.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 45.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 45.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 45.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 45.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 45.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 45.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 45.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 45.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 45.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 46.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 46.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 46.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 46.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 46.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 46.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 46.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 46.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 46.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 46.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 47.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 47.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 47.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 47.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 47.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 47.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 47.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 47.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 47.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 47.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 48.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 48.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 48.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 48.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 48.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 48.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 48.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 48.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 48.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 48.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 49.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 49.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 49.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 49.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 49.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 49.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 49.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 49.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 49.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 49.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 50.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 50.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 50.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 50.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 50.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 50.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 50.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 50.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 50.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 50.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 51.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 51.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 51.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 51.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 51.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 51.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 51.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 51.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 51.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 51.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 52.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 52.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 52.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 52.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 52.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 52.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 52.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 52.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 52.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 52.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 53.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 53.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 53.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 53.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 53.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 53.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 53.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 53.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 53.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 53.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 54.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 54.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 54.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 54.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 54.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 54.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 54.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 54.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 54.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 54.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 55.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 55.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 55.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 55.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 55.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 55.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 55.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 55.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 55.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 55.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 56.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 56.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 56.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 56.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 56.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 56.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 56.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 56.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 56.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 56.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 57.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 57.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 57.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 57.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 57.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 57.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 57.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 57.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 57.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 57.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 58.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 58.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 58.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 58.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 58.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 58.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 58.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 58.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 58.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 58.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 59.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 59.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 59.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 59.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 59.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 59.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 59.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 59.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 59.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 59.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:0.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:0.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:0.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:0.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:0.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:0.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:0.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:0.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:0.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:0.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:1.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:1.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:1.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:1.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:1.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:1.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:1.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:1.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:1.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:1.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:2.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:2.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:2.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:2.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:2.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:2.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:2.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:2.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:2.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:2.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:3.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:3.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:3.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:3.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:3.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:3.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:3.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:3.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:3.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:3.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:4.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:4.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:4.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:4.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:4.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:4.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:4.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:4.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:4.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:4.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:5.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:5.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:5.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:5.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:5.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:5.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:5.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:5.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:5.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:5.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:6.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:6.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:6.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:6.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:6.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:6.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:6.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:6.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:6.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:6.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:7.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:7.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:7.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:7.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:7.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:7.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:7.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:7.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:7.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:7.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:8.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:8.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:8.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:8.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:8.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:8.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:8.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:8.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:8.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:8.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:9.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:9.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:9.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:9.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:9.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:9.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:9.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:9.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:9.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:9.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:10.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:10.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:10.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:10.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:10.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:10.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:10.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:10.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1m:10.8s
# Downloading      100%
# Extracting   (1)  ⣾
# Downloading and Extracting Packages:
#
# done
# done
# \ By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# done

# %%
# please paste your api key for the deepseek R1 free model here
my_api_key=""

# %%
# Query Preprocessor
from query_preprocessor import QueryPreprocessor

preprocessor = QueryPreprocessor(
  min_query_length=2,
  max_query_length=256,
  enable_spell_check=True
)

query = "What's   the mechanism of COVID-19 vaccination?   What evne is covid? How do we stpo it?"
processed_query = preprocessor.preprocess(query)
print(processed_query)
# Out:
# ['what is the mechanism of covid-19 vaccination?', 'what even is covid?', 'how do we stop it?']

# %%
# Document Loader
from document_loader import DocumentLoader

loader = DocumentLoader()
sample_pdf = "chocolate_cake_recipe.pdf"

text, metadata = loader.load_document(sample_pdf)

print(f"Successfully parsed {metadata['page_count']} pages from {sample_pdf}")
print(f"Tile: {metadata.get('title', 'N/A')}")
print(f"Cleaned Text:\n {text}")
# Out:
# Successfully parsed 3 pages from chocolate_cake_recipe.pdf
# Tile: Chocolate Cake | RecipeTin Eats
# Cleaned Text:
#  29/3/18, 12)34 pm
# Chocolate Cake | RecipeTin Eats
# Page 1 of 3
# https://www.recipetineats.com/?p=28074&preview=true
# Prep Time
# 10 mins
# Cook Time
# 35 mins
# Total Time
# 45 mins
# Chocolate Cake
#
# This is the everyday Chocolate Cake I make over and over again. The crumb is
# tender and moist, it truly tastes of chocolate (rarer than you might think!) and
# you only need one bowl and a whisk. It's the famous Hershey's "Perfectly
# Chocolate" Cake and quite possibly the only recipe on this entire site that I use as
# written, without any changes to the ingredients (but don't skip my baking tips in
# the notes!). Recipe VIDEO below.
# Servings: 8 -10 slices
# Author: Nagi
# Ingredients
# 2 cups / 440g white sugar (Note 1)
# 1 3/4 cups / 265g plain / all purpose flour
# 3/4 cup / 55g cocoa powder , unsweetened (Note 2)
# 1 1/2 tsp baking powder
# 1 1/2 tsp baking soda
# 1 tsp salt
# 2 eggs (~55-65g / 2 oz each)
# 1 cup / 250 ml milk (low or full fat)
# 1/2 cup / 125 ml vegetable oil (or canola)
# 2 tsp vanilla extract
# 1 cup / 250 ml boiling water
# Instructions
# 1. Preheat oven to 180C/350F (standard) or 160C / 320F (fan/convection).
# 2. Read Note 4 regarding shelf positions.
# 3. Grease 2 x 22cm/9" cake pans with butter, then line the base. (See Note 3 regarding springform pans).
# Batter:
# 1. Place sugar, flour, cocoa, baking powder and salt in a large bowl. Whisk briefly to combine.
# 2. Add eggs, milk, oil and vanilla. Whisk well to combine until lump free - about 30 seconds.
# 3. Add boiling water and whisk to incorporate. The batter is VERY thin (see video).
# 4. Pour batter into cake pans.
# Baking:
# 1. Bake for 35 minutes or until a wooden skewer inserted into the centre comes out clean. See Note 4
# regarding cook time if pans are on different shelves.
# 2. Cool for 10 minutes, then turn out onto wire racks upside down (Note 5).
# 3. Cool completely before frosting. I frosted the cake with my Chocolate Buttercream Frosting (scale
# recipe up by 50%).
# Recipe Notes
# 1. I use caster / superfine out of habit for all baking recipes, but regular is ok too.
# 2. Regular cocoa powder words just fine here, but dutch processed will make it a slightly more intense
# chocolate flavour. I use regular for this cake.
# 3. SPRINGFORM PAN (important): Even the best ones are not 100% leakproof so with very thin batters like
# with this cake, you will get a small amount of leakage. The best way to combat this is to "plug" the space
# where the sides meets the base with butter, and place a tray on the bottom of the oven to catch drips (don't
#
# 29/3/18, 12)34 pm
# Chocolate Cake | RecipeTin Eats
# Page 2 of 3
# https://www.recipetineats.com/?p=28074&preview=true
# put cake pans on the tray, it affects heat circulation).
# Quick way to make cake pan liners: take a piece of baking paper and folder in half, then quarters, then keep
# folding so it's a small long triangle. Line up the middle with the middle of the cake pan, then snip the end
# off. Unfold and voila! A near perfect round cake pan liner!
# 4. BAKING / SHELVES - If your oven is large enough for both cake pans to be on one shelf, place the shelf in
# the middle of the oven. If it's not large enough, put one shelf 1/3 of the way down the oven, then the next
# shelf below it (check to ensure cake pan fits). If cakes are on separate shelves, take out the top one at 35
# minutes per recipe, then move the bottom one up to the top shelf and bake for a further 5 minutes.
# 5. I turn the cakes out upside down so the flat base becomes the surface used for frosting. Flat surface just
# looks nicer when you cut into the cake! This cake comes out pretty level, but if you want to be extra neat,
# feel free to level the cakes using a serrated knife.
# 6. EASTER DECORATIONS as pictured in post and in the Easter Recipes post: baby chicks $2, speckled
# chocolate eggs and shredded paper all fromWoolies. Chocolate basket made as follows: blow up balloon to
# the size you want the basket to be, place with tied end down in a rice bowl or something it fits in. Melt
# baking chocolate in microwave (about 1/2 cup chips/buttons), then transfer into small ziplock bag. Snip
# corner, then drizzle chocolate over exposed half of balloon. Let set in fridge, then carefully release air from
# balloon. Voila! Chocolate basket! Fill with shredded paper, eggs and chicks.
#
# 29/3/18, 12)34 pm
# Chocolate Cake | RecipeTin Eats
# Page 3 of 3
# https://www.recipetineats.com/?p=28074&preview=true
#
# Another great recipe by www.recipetineats.com

# %%
# Text Chunker
from text_chunker import TextChunker

chunker = TextChunker(chunk_size=512, chunk_overlap=128) # standard values
chunks = chunker.chunk_text(text, metadata)

print(f"Generated {len(chunks)} chunks:")
for i, chunk in enumerate(chunks):
  print(f"\nChunk {i+1} (Chars: {len(chunk['text'])}):")
  print(chunk['text'])
  print(f"Metadata: {chunk['metadata']}")
# Out:
# Generated 13 chunks:
#
# Chunk 1 (Chars: 501):
# 29/3/18, 12)34 pm
# Chocolate Cake | RecipeTin Eats
# Page 1 of 3
# https://www.recipetineats.com/?p=28074&preview=true
# Prep Time
# 10 mins
# Cook Time
# 35 mins
# Total Time
# 45 mins
# Chocolate Cake
#
# This is the everyday Chocolate Cake I make over and over again. The crumb is
# tender and moist, it truly tastes of chocolate (rarer than you might think!) and
# you only need one bowl and a whisk. It's the famous Hershey's "Perfectly
# Chocolate" Cake and quite possibly the only recipe on this entire site that I use as
# Metadata: {'page_count': 3, 'author': 'Nagi Maehashi', 'title': 'Chocolate Cake | RecipeTin Eats', 'chunk_index': 0}
#
# Chunk 2 (Chars: 500):
# Chocolate" Cake and quite possibly the only recipe on this entire site that I use as
# written, without any changes to the ingredients (but don't skip my baking tips in
# the notes!). Recipe VIDEO below.
# Servings: 8 -10 slices
# Author: Nagi
# Ingredients
# 2 cups / 440g white sugar (Note 1)
# 1 3/4 cups / 265g plain / all purpose flour
# 3/4 cup / 55g cocoa powder , unsweetened (Note 2)
# 1 1/2 tsp baking powder
# 1 1/2 tsp baking soda
# 1 tsp salt
# 2 eggs (~55-65g / 2 oz each)
# 1 cup / 250 ml milk (low or full fat)
# Metadata: {'page_count': 3, 'author': 'Nagi Maehashi', 'title': 'Chocolate Cake | RecipeTin Eats', 'chunk_index': 1}
#
# Chunk 3 (Chars: 458):
# 1 1/2 tsp baking powder
# 1 1/2 tsp baking soda
# 1 tsp salt
# 2 eggs (~55-65g / 2 oz each)
# 1 cup / 250 ml milk (low or full fat)
# 1/2 cup / 125 ml vegetable oil (or canola)
# 2 tsp vanilla extract
# 1 cup / 250 ml boiling water
# Instructions
# 1. Preheat oven to 180C/350F (standard) or 160C / 320F (fan/convection).
# 2. Read Note 4 regarding shelf positions.
# 3. Grease 2 x 22cm/9" cake pans with butter, then line the base. (See Note 3 regarding springform pans).
# Batter:
# Metadata: {'page_count': 3, 'author': 'Nagi Maehashi', 'title': 'Chocolate Cake | RecipeTin Eats', 'chunk_index': 2}
#
# Chunk 4 (Chars: 425):
# 3. Grease 2 x 22cm/9" cake pans with butter, then line the base. (See Note 3 regarding springform pans).
# Batter:
# 1. Place sugar, flour, cocoa, baking powder and salt in a large bowl. Whisk briefly to combine.
# 2. Add eggs, milk, oil and vanilla. Whisk well to combine until lump free - about 30 seconds.
# 3. Add boiling water and whisk to incorporate. The batter is VERY thin (see video).
# 4. Pour batter into cake pans.
# Baking:
# Metadata: {'page_count': 3, 'author': 'Nagi Maehashi', 'title': 'Chocolate Cake | RecipeTin Eats', 'chunk_index': 3}
#
# Chunk 5 (Chars: 486):
# 3. Add boiling water and whisk to incorporate. The batter is VERY thin (see video).
# 4. Pour batter into cake pans.
# Baking:
# 1. Bake for 35 minutes or until a wooden skewer inserted into the centre comes out clean. See Note 4
# regarding cook time if pans are on different shelves.
# 2. Cool for 10 minutes, then turn out onto wire racks upside down (Note 5).
# 3. Cool completely before frosting. I frosted the cake with my Chocolate Buttercream Frosting (scale
# recipe up by 50%).
# Recipe Notes
# Metadata: {'page_count': 3, 'author': 'Nagi Maehashi', 'title': 'Chocolate Cake | RecipeTin Eats', 'chunk_index': 4}
#
# Chunk 6 (Chars: 482):
# recipe up by 50%).
# Recipe Notes
# 1. I use caster / superfine out of habit for all baking recipes, but regular is ok too.
# 2. Regular cocoa powder words just fine here, but dutch processed will make it a slightly more intense
# chocolate flavour. I use regular for this cake.
# 3. SPRINGFORM PAN (important): Even the best ones are not 100% leakproof so with very thin batters like
# with this cake, you will get a small amount of leakage. The best way to combat this is to "plug" the space
# Metadata: {'page_count': 3, 'author': 'Nagi Maehashi', 'title': 'Chocolate Cake | RecipeTin Eats', 'chunk_index': 5}
#
# Chunk 7 (Chars: 215):
# with this cake, you will get a small amount of leakage. The best way to combat this is to "plug" the space
# where the sides meets the base with butter, and place a tray on the bottom of the oven to catch drips (don't
# Metadata: {'page_count': 3, 'author': 'Nagi Maehashi', 'title': 'Chocolate Cake | RecipeTin Eats', 'chunk_index': 6}
#
# Chunk 8 (Chars: 449):
# 29/3/18, 12)34 pm
# Chocolate Cake | RecipeTin Eats
# Page 2 of 3
# https://www.recipetineats.com/?p=28074&preview=true
# put cake pans on the tray, it affects heat circulation).
# Quick way to make cake pan liners: take a piece of baking paper and folder in half, then quarters, then keep
# folding so it's a small long triangle. Line up the middle with the middle of the cake pan, then snip the end
# off. Unfold and voila! A near perfect round cake pan liner!
# Metadata: {'page_count': 3, 'author': 'Nagi Maehashi', 'title': 'Chocolate Cake | RecipeTin Eats', 'chunk_index': 7}
#
# Chunk 9 (Chars: 485):
# off. Unfold and voila! A near perfect round cake pan liner!
# 4. BAKING / SHELVES - If your oven is large enough for both cake pans to be on one shelf, place the shelf in
# the middle of the oven. If it's not large enough, put one shelf 1/3 of the way down the oven, then the next
# shelf below it (check to ensure cake pan fits). If cakes are on separate shelves, take out the top one at 35
# minutes per recipe, then move the bottom one up to the top shelf and bake for a further 5 minutes.
# Metadata: {'page_count': 3, 'author': 'Nagi Maehashi', 'title': 'Chocolate Cake | RecipeTin Eats', 'chunk_index': 8}
#
# Chunk 10 (Chars: 469):
# minutes per recipe, then move the bottom one up to the top shelf and bake for a further 5 minutes.
# 5. I turn the cakes out upside down so the flat base becomes the surface used for frosting. Flat surface just
# looks nicer when you cut into the cake! This cake comes out pretty level, but if you want to be extra neat,
# feel free to level the cakes using a serrated knife.
# 6. EASTER DECORATIONS as pictured in post and in the Easter Recipes post: baby chicks $2, speckled
# Metadata: {'page_count': 3, 'author': 'Nagi Maehashi', 'title': 'Chocolate Cake | RecipeTin Eats', 'chunk_index': 9}
#
# Chunk 11 (Chars: 412):
# 6. EASTER DECORATIONS as pictured in post and in the Easter Recipes post: baby chicks $2, speckled
# chocolate eggs and shredded paper all fromWoolies. Chocolate basket made as follows: blow up balloon to
# the size you want the basket to be, place with tied end down in a rice bowl or something it fits in. Melt
# baking chocolate in microwave (about 1/2 cup chips/buttons), then transfer into small ziplock bag. Snip
# Metadata: {'page_count': 3, 'author': 'Nagi Maehashi', 'title': 'Chocolate Cake | RecipeTin Eats', 'chunk_index': 10}
#
# Chunk 12 (Chars: 292):
# baking chocolate in microwave (about 1/2 cup chips/buttons), then transfer into small ziplock bag. Snip
# corner, then drizzle chocolate over exposed half of balloon. Let set in fridge, then carefully release air from
# balloon. Voila! Chocolate basket! Fill with shredded paper, eggs and chicks.
# Metadata: {'page_count': 3, 'author': 'Nagi Maehashi', 'title': 'Chocolate Cake | RecipeTin Eats', 'chunk_index': 11}
#
# Chunk 13 (Chars: 161):
# 29/3/18, 12)34 pm
# Chocolate Cake | RecipeTin Eats
# Page 3 of 3
# https://www.recipetineats.com/?p=28074&preview=true
#
# Another great recipe by www.recipetineats.com
# Metadata: {'page_count': 3, 'author': 'Nagi Maehashi', 'title': 'Chocolate Cake | RecipeTin Eats', 'chunk_index': 12}

# %%
# Embedding Generator
from embedding_generator import EmbeddingGenerator

embedder = EmbeddingGenerator(model_name="mpnet")

# ----------------------------------------------------
samples = [
    "Neural networks are computing systems inspired by biological brains.",
    "Transformer models use attention mechanisms to process text.",
    "Chicken is a great source of protein."
]
embeddings = embedder.embed_text(samples)

from sklearn.metrics.pairwise import cosine_similarity

print("Similarity between sample texts:")
print(cosine_similarity([embeddings[0]], [embeddings[1]]))
print(cosine_similarity([embeddings[0]], [embeddings[2]]))
# ----------------------------------------------------

embeddings = embedder.embed_text(chunks)

print(f"Using model: {embedder.get_model_info()['name']}")
print(f"Embedding dimensions: {embedder.embedding_size}")
print(f"Generated {len(embeddings)} embeddings")
print(f"First embedding vector (length {len(embeddings[0])}):")
print(embeddings[0][:10])  # Show first 10 dimensions
# Out:
# Similarity between sample texts:
# [[0.32122013]]
# [[0.06740446]]
# Using model: mpnet
# Embedding dimensions: 768
# Generated 13 embeddings
# First embedding vector (length 768):
# [ 0.05461106 -0.02150607  0.01168926 -0.01334951 -0.07141707  0.00237363
#  -0.08287673 -0.00474756 -0.06211413  0.04496194]

# %%
# Vector Store
from vector_store import VectorStore

vector_str = VectorStore(dimension=768, index_path="my_index")

vector_str.add_chunks(embeddings, chunks)
print(f"Index contains {vector_str.get_index_size()} chunks")

query = "What's the best cocoa powder to use in this recipe?"
query_embedding = embedder.embed_text(query)

results = vector_str.search(query_embedding, k=5)
print("\nTop results:")
for i, res in enumerate(results):
  print(f"\nResult #{i+1} (Similarity: {res['similarity']:.4f})")
  print(f"Text: {res['chunk']}...")
  print(f"Metadata: {res['metadata']}")

vector_str.save_index()
# Out:
# Index contains 13 chunks
#
# Top results:
#
# Result #1 (Similarity: 0.5892)
# Text: recipe up by 50%).
# Recipe Notes
# 1. I use caster / superfine out of habit for all baking recipes, but regular is ok too.
# 2. Regular cocoa powder words just fine here, but dutch processed will make it a slightly more intense
# chocolate flavour. I use regular for this cake.
# 3. SPRINGFORM PAN (important): Even the best ones are not 100% leakproof so with very thin batters like
# with this cake, you will get a small amount of leakage. The best way to combat this is to "plug" the space...
# Metadata: {'page_count': 3, 'author': 'Nagi Maehashi', 'title': 'Chocolate Cake | RecipeTin Eats', 'chunk_index': 5}
#
# Result #2 (Similarity: 0.4688)
# Text: Chocolate" Cake and quite possibly the only recipe on this entire site that I use as
# written, without any changes to the ingredients (but don't skip my baking tips in
# the notes!). Recipe VIDEO below.
# Servings: 8 -10 slices
# Author: Nagi
# Ingredients
# 2 cups / 440g white sugar (Note 1)
# 1 3/4 cups / 265g plain / all purpose flour
# 3/4 cup / 55g cocoa powder , unsweetened (Note 2)
# 1 1/2 tsp baking powder
# 1 1/2 tsp baking soda
# 1 tsp salt
# 2 eggs (~55-65g / 2 oz each)
# 1 cup / 250 ml milk (low or full fat)...
# Metadata: {'page_count': 3, 'author': 'Nagi Maehashi', 'title': 'Chocolate Cake | RecipeTin Eats', 'chunk_index': 1}
#
# Result #3 (Similarity: 0.4256)
# Text: 29/3/18, 12)34 pm
# Chocolate Cake | RecipeTin Eats
# Page 1 of 3
# https://www.recipetineats.com/?p=28074&preview=true
# Prep Time
# 10 mins
# Cook Time
# 35 mins
# Total Time
# 45 mins
# Chocolate Cake
#
# This is the everyday Chocolate Cake I make over and over again. The crumb is
# tender and moist, it truly tastes of chocolate (rarer than you might think!) and
# you only need one bowl and a whisk. It's the famous Hershey's "Perfectly
# Chocolate" Cake and quite possibly the only recipe on this entire site that I use as...
# Metadata: {'page_count': 3, 'author': 'Nagi Maehashi', 'title': 'Chocolate Cake | RecipeTin Eats', 'chunk_index': 0}
#
# Result #4 (Similarity: 0.3790)
# Text: 29/3/18, 12)34 pm
# Chocolate Cake | RecipeTin Eats
# Page 3 of 3
# https://www.recipetineats.com/?p=28074&preview=true
#
# Another great recipe by www.recipetineats.com...
# Metadata: {'page_count': 3, 'author': 'Nagi Maehashi', 'title': 'Chocolate Cake | RecipeTin Eats', 'chunk_index': 12}
#
# Result #5 (Similarity: 0.3620)
# Text: 1 1/2 tsp baking powder
# 1 1/2 tsp baking soda
# 1 tsp salt
# 2 eggs (~55-65g / 2 oz each)
# 1 cup / 250 ml milk (low or full fat)
# 1/2 cup / 125 ml vegetable oil (or canola)
# 2 tsp vanilla extract
# 1 cup / 250 ml boiling water
# Instructions
# 1. Preheat oven to 180C/350F (standard) or 160C / 320F (fan/convection).
# 2. Read Note 4 regarding shelf positions.
# 3. Grease 2 x 22cm/9" cake pans with butter, then line the base. (See Note 3 regarding springform pans).
# Batter:...
# Metadata: {'page_count': 3, 'author': 'Nagi Maehashi', 'title': 'Chocolate Cake | RecipeTin Eats', 'chunk_index': 2}
# Index was loaded from my_index.index and my_index.meta

# %%
# Reranker
from reranker import Reranker

ranker = Reranker()
reranked = ranker.rerank(query, results, top_k=5)

for i, result in enumerate(reranked):
  print(f"Result {i+1}: {result}")
# Out:
# Result 1: {'chunk': 'recipe up by 50%).\nRecipe Notes\n1. I use caster / superfine out of habit for all baking recipes, but regular is ok too.\n2. Regular cocoa powder words just fine here, but dutch processed will make it a slightly more intense\nchocolate flavour. I use regular for this cake. \n3. SPRINGFORM PAN (important): Even the best ones are not 100% leakproof so with very thin batters like\nwith this cake, you will get a small amount of leakage. The best way to combat this is to "plug" the space', 'metadata': {'page_count': 3, 'author': 'Nagi Maehashi', 'title': 'Chocolate Cake | RecipeTin Eats', 'chunk_index': 5}, 'similarity': 0.5891648530960083, 'relevance': 4.114064693450928}
# Result 2: {'chunk': 'Chocolate" Cake and quite possibly the only recipe on this entire site that I use as\nwritten, without any changes to the ingredients (but don\'t skip my baking tips in\nthe notes!). Recipe VIDEO below.\nServings: 8 -10 slices\nAuthor: Nagi\nIngredients\n2 cups / 440g white sugar (Note 1)\n1 3/4 cups / 265g plain / all purpose flour\n3/4 cup / 55g cocoa powder , unsweetened (Note 2)\n1 1/2 tsp baking powder\n1 1/2 tsp baking soda\n1 tsp salt\n2 eggs (~55-65g / 2 oz each)\n1 cup / 250 ml milk (low or full fat)', 'metadata': {'page_count': 3, 'author': 'Nagi Maehashi', 'title': 'Chocolate Cake | RecipeTin Eats', 'chunk_index': 1}, 'similarity': 0.468797892332077, 'relevance': 0.2779543697834015}
# Result 3: {'chunk': '1 1/2 tsp baking powder\n1 1/2 tsp baking soda\n1 tsp salt\n2 eggs (~55-65g / 2 oz each)\n1 cup / 250 ml milk (low or full fat)\n1/2 cup / 125 ml vegetable oil (or canola)\n2 tsp vanilla extract\n1 cup / 250 ml boiling water\nInstructions\n1. Preheat oven to 180C/350F (standard) or 160C / 320F (fan/convection).\n2. Read Note 4 regarding shelf positions.\n3. Grease 2 x 22cm/9" cake pans with butter, then line the base. (See Note 3 regarding springform pans).\nBatter:', 'metadata': {'page_count': 3, 'author': 'Nagi Maehashi', 'title': 'Chocolate Cake | RecipeTin Eats', 'chunk_index': 2}, 'similarity': 0.3619956970214844, 'relevance': -7.423851490020752}
# Result 4: {'chunk': '29/3/18, 12)34 pm\nChocolate Cake | RecipeTin Eats\nPage 1 of 3\nhttps://www.recipetineats.com/?p=28074&preview=true\nPrep Time\n10 mins\nCook Time\n35 mins\nTotal Time\n45 mins\nChocolate Cake\n \nThis is the everyday Chocolate Cake I make over and over again. The crumb is\ntender and moist, it truly tastes of chocolate (rarer than you might think!) and\nyou only need one bowl and a whisk. It\'s the famous Hershey\'s "Perfectly\nChocolate" Cake and quite possibly the only recipe on this entire site that I use as', 'metadata': {'page_count': 3, 'author': 'Nagi Maehashi', 'title': 'Chocolate Cake | RecipeTin Eats', 'chunk_index': 0}, 'similarity': 0.4255801737308502, 'relevance': -9.249093055725098}
# Result 5: {'chunk': '29/3/18, 12)34 pm\nChocolate Cake | RecipeTin Eats\nPage 3 of 3\nhttps://www.recipetineats.com/?p=28074&preview=true\n \nAnother great recipe by www.recipetineats.com', 'metadata': {'page_count': 3, 'author': 'Nagi Maehashi', 'title': 'Chocolate Cake | RecipeTin Eats', 'chunk_index': 12}, 'similarity': 0.3790045976638794, 'relevance': -9.564867973327637}

# %%
# Prompt Engineer
from prompt_engineer import PromptEngineer

prompt_eng = PromptEngineer()
prompt = prompt_eng.format_prompt(processed_query=query, context_chunks=reranked)

print("Generated Prompt: ")
print(prompt)
# Out:
# Generated Prompt:
# You are an expert research assistant. Your task is to answer questions based ONLY on the provided context.
# RULES:
# 1. Answer the question using ONLY the context provided
# 2. If the question cannot be answered with the context, say "I could not find an answer in the provided document(s)"
# 3. Be concise but comprehensive
# 4. Never invent information not present in the context
#
# CONTEXT DOCUMENTS:
# ### CONTEXT 1 [Relevance: 4.11]
# CONTENT: recipe up by 50%).
# Recipe Notes
# 1. I use caster / superfine out of habit for all baking recipes, but regular is ok too.
# 2. Regular cocoa powder words just fine here, but dutch processed will make it a slightly more intense
# chocolate flavour. I use regular for this cake.
# 3. SPRINGFORM PAN (important): Even the best ones are not 100% leakproof so with very thin batters like
# with this cake, you will get a small amount of leakage. The best way to combat this is to "plug" the space
#
# ### CONTEXT 2 [Relevance: 0.28]
# CONTENT: Chocolate" Cake and quite possibly the only recipe on this entire site that I use as
# written, without any changes to the ingredients (but don't skip my baking tips in
# the notes!). Recipe VIDEO below.
# Servings: 8 -10 slices
# Author: Nagi
# Ingredients
# 2 cups / 440g white sugar (Note 1)
# 1 3/4 cups / 265g plain / all purpose flour
# 3/4 cup / 55g cocoa powder , unsweetened (Note 2)
# 1 1/2 tsp baking powder
# 1 1/2 tsp baking soda
# 1 tsp salt
# 2 eggs (~55-65g / 2 oz each)
# 1 cup / 250 ml milk (low or full fat)
#
# ### CONTEXT 3 [Relevance: -7.42]
# CONTENT: 1 1/2 tsp baking powder
# 1 1/2 tsp baking soda
# 1 tsp salt
# 2 eggs (~55-65g / 2 oz each)
# 1 cup / 250 ml milk (low or full fat)
# 1/2 cup / 125 ml vegetable oil (or canola)
# 2 tsp vanilla extract
# 1 cup / 250 ml boiling water
# Instructions
# 1. Preheat oven to 180C/350F (standard) or 160C / 320F (fan/convection).
# 2. Read Note 4 regarding shelf positions.
# 3. Grease 2 x 22cm/9" cake pans with butter, then line the base. (See Note 3 regarding springform pans).
# Batter:
#
# ### CONTEXT 4 [Relevance: -9.25]
# CONTENT: 29/3/18, 12)34 pm
# Chocolate Cake | RecipeTin Eats
# Page 1 of 3
# https://www.recipetineats.com/?p=28074&preview=true
# Prep Time
# 10 mins
# Cook Time
# 35 mins
# Total Time
# 45 mins
# Chocolate Cake
#
# This is the everyday Chocolate Cake I make over and over again. The crumb is
# tender and moist, it truly tastes of chocolate (rarer than you might think!) and
# you only need one bowl and a whisk. It's the famous Hershey's "Perfectly
# Chocolate" Cake and quite possibly the only recipe on this entire site that I use as
#
# ### CONTEXT 5 [Relevance: -9.56]
# CONTENT: 29/3/18, 12)34 pm
# Chocolate Cake | RecipeTin Eats
# Page 3 of 3
# https://www.recipetineats.com/?p=28074&preview=true
#
# Another great recipe by www.recipetineats.com
#
# QUESTION: What's the best cocoa powder to use in this recipe?
#
# ANSWER:

# %%
# Full implementation
import time
from deepseek_llm import DeepSeekLLM
import numpy as np

# define top k
top_k = 30
final_k = 5

# init pipeline parts
preprocessor = QueryPreprocessor(
  min_query_length=2,
  max_query_length=256,
  enable_spell_check=True
)
loader = DocumentLoader()
chunker = TextChunker(chunk_size=512, chunk_overlap=128)
embedder = EmbeddingGenerator(model_name="mpnet")
vector_str = VectorStore(dimension=768, index_path="my_index")
ranker = Reranker()
prompt_eng = PromptEngineer(max_content_length=160000)
llm = DeepSeekLLM(api_key=my_api_key)

# user input
doc_path = input("Hello! Welcome to the Document Question Answering Model by Vedik Upadhyay. Please enter the path for the document you wish to use: ")
query = input("What's your question?\n")

# pipeline
start = time.time()
questions = preprocessor.preprocess(query)
print(f"Processing query... {time.time() - start:.2f}s")

start = time.time()
text, metadata = loader.load_document(doc_path)
print(f"Loading text... {time.time() - start:.2f}s")

start = time.time()
chunks = chunker.chunk_text(text, metadata)
print(f"Chunking context... {time.time() - start:.2f}s")

start = time.time()
embeddings = embedder.embed_text(chunks)
print(f"Embedding chunks... {time.time() - start:.2f}s")

start = time.time()
vector_str.add_chunks(embeddings, chunks)
print(f"Storing embeddings... {time.time() - start:.2f}s")

start = time.time()
for q in questions:
  q_embed = embedder.embed_text(q)
  results = vector_str.search(q_embed, k=top_k)
  reranked = ranker.rerank(q, results, top_k=final_k)
  prompt = prompt_eng.format_prompt(processed_query=q, context_chunks=reranked)
  answer = llm.answer_query(prompt)
  print(f"Answering Questions... {time.time() - start:.2f}s")
  print(f"\n\nQuestion: {q}\nAnswer: {answer}")
# Out:
# Hello! Welcome to the Document Question Answering Model by Vedik Upadhyay. Please enter the path for the document you wish to use: nytimes_article.pdf
# What's your question?
# Is the World Cup going to be canceled? Why do fans fear immigration?
# Processing query... 0.00s
# Loading text... 0.03s
# Chunking context... 0.00s
# Embedding chunks... 0.19s
# Storing embeddings... 0.00s
# Answering Questions... 14.53s
#
#
# Question: is the world cup going to be cancelled
# Answer: Based solely on the provided context:
#
# 1.  **The World Cup itself is not cancelled.** Context 2 explicitly states: "It is expected to draw about 6.5 million people, mostly to the United States, where most matches will be played" and Context 3 mentions "next summer’s World Cup".
# 2.  **A specific game or event related to the World Cup was cancelled.** Context 1 describes the cancellation of a game  due to fears of immigration raids targeting fans without legal status. This cancellation is described as a "preview" of how immigration policies *might affect* the World Cup, not the cancellation of the tournament itself.
#
# **Answer:** No, the World Cup is not cancelled. The context describes the cancellation of a specific game due to immigration concerns, but the World Cup tournament itself is still planned and referenced as upcoming.
# Answering Questions... 46.64s
#
#
# Question: why do fans fear immigration?
# Answer: Based solely on the provided context, fans fear immigration raids because:
#
# 1.  Many fans are from outside the United States and lack legal immigration status .
# 2.  They fear being targeted by U.S. immigration enforcement actions, specifically being "snatched off the streets" and arrested .
# 3.  This fear stems from the Trump administration's immigration policies and crackdown .
# 4.  The fear is so significant that fan groups have canceled watch parties and group travel plans  to avoid becoming targets of raids .
